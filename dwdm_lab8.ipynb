# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriharshitha842/DWDM_LAB/blob/main/dwdm_lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NAME OF THE STUDENT : SRIHARSHITHA DEEPALA**
#
# **REGISTRATION NUMBER : 19BCD7246**
#
# **COURSE CODE : CSE4005**
#
# **SLOT NUMBER : L31+L32+L15+L16+L23+L24**
#
# **LAB NUMBER : 08**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def countlist(arr):
  count=0
  for i in range(0,len(arr)):
     if arr[i][0]=='a'or arr[i][1]=='b' or arr[i][2]=='c':
        count=count+1
     else:
        pass
  return count
countlist([['a','b','c','d'],['b','c','d'],['b','c','d','e'],['a','b','c','d','e']] )
# Out:
# 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def selfjoin(arr):
  x=[]
  count=0
  for i in range(0,len(arr)):
    if arr[i-1][0]==arr[i][0]:
      y=[arr[i-1][0],arr[i-1][1],arr[i][1]]
      x.append(y)
  return x
selfjoin([['a','b'],['a','c'],['b','c'],['b','d'],['c','d'],['c','e'],['c','f']])
# Out:
# [['a', 'b', 'c'], ['b', 'c', 'd'], ['c', 'd', 'e'], ['c', 'e', 'f']]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a='a'
b='b'
c='c'
import itertools
def findsubsets(s,n):
  return list(itertools.combinations(s,n))
s={a,b,c}
n=1
a=findsubsets(s,n)
n=2
b=findsubsets(s,n)
c=a+b
print(c)
# Out:
# [('c',), ('a',), ('b',), ('c', 'a'), ('c', 'b'), ('a', 'b')]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
dataset = [["a","b","c"], ["a","b"], ["a","b","d"], ["b","e"],
["b","c","e"], ["a","d","e"], ["a","c"], ["a","b","d"],
["c","e"], ["a","b","d","e"], ["a","b","e","c"]]
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
apriori(df, use_colnames=True)
# Out:
#     support itemsets
# 0  0.727273      (a)
# 1  0.727273      (b)
# 2  0.545455      (e)
# 3  0.545455   (a, b)
